# %%
from PIL import Image
import numpy as np

# %%
bg_crop_path = "D:/Documents/13_Projet/dlcv4ldb/02_Donnees/empty_maps/incarnam/champs/crop/incarnam_champs_0_-4_lv5.jpg"
bg_mask_path = "D:/Documents/13_Projet/dlcv4ldb/02_Donnees/empty_maps/incarnam/champs/mask/incarnam_champs_0_-4_lv5.jpg"

# %%
bg_img = Image.open(bg_crop_path, 'r')
bg_mask = Image.open(bg_mask_path, 'r').convert('L')

# %%
bg_mask.size
# Out:
# (1210, 875)

# %%
np.array(bg_mask).shape
# Out:
# (875, 1210)

# %%
bg_mask
# Out:
# <PIL.Image.Image image mode=L size=1210x875>
