# %%
from PIL import Image

# %%
bg_path = "D:/Documents/13_Projet/dlcv4ldb/02_Donnees/empty_maps/incarnam/cimetiere/incarnam_cimetiere_3_1_lv10.jpg"
sticker_path = "D:/Documents/13_Projet/dlcv4ldb/02_Donnees/stickers/incarnam/mobs/cimetiere/chaferDebutant/nobg/chaferDebutant_NE_BG-removebg-preview.png"

# %%
bg_img = Image.open(bg_path, 'r')
sticker_img = Image.open(sticker_path, 'r')

# %%
sticker_img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=131x119>

# %%
# new_img = Image.new('RGBA', bg_img.size , (0, 0, 0))
new_img = bg_img.copy()

# %%
new_img.paste(bg_img, (0, 0))

# %%
new_img.size
# Out:
# (1920, 1020)

# %%
new_img.paste(sticker_img, (new_img.size[0]//2, new_img.size[1]//2), mask=sticker_img)

# %%
new_img
# Out:
# <PIL.Image.Image image mode=RGB size=1920x1020>
