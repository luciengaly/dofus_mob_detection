# %%
from PIL import Image

# %%
bg_path = "D:/Documents/13_Projet/dlcv4ldb/02_Donnees/empty_maps/incarnam/cimetiere/incarnam_cimetiere_3_1_lv10.jpg"

# %%
bg_img = Image.open(bg_path, 'r')

# %%
bg_img.size
# Out:
# (1920, 1020)

# %%
img_crop = bg_img.crop((355, 10, bg_img.size[0] - 355, bg_img.size[1] - 135))

# %%
img_crop
# Out:
# <PIL.Image.Image image mode=RGB size=1210x875>
